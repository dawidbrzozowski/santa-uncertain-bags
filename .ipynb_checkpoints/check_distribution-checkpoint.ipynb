# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %%
def plot_distrib(avg, var, shift=0, size=5, distrib=stats.norm.pdf):
    sigma = math.sqrt(var)
    x = np.linspace(avg - size*sigma, avg + size*sigma, 100)
    plt.plot(x, distrib(x - shift, avg, sigma))
    plt.show()

# %%
def plot_triangular(left, mode, right): #needs to be corrected
    x = np.linspace(0, 30, 100)
    print(x)
    plt.plot(x, stats.triang.pdf(x, left, mode, right))

# %%
# horse = max(0, np.random.normal(5,2,1)[0])
plot_distrib(avg=5, var=2, distrib = stats.norm.pdf)

# %%
# ball = max(0, 1 + np.random.normal(1,0.3,1)[0])
plot_distrib(avg=1, var=0.3, shift=1)

# %%
# bike = max(0, np.random.normal(20,10,1)[0])
plot_distrib(avg=20, var=10)

# %%
# train = max(0, np.random.normal(10,5,1)[0])
plot_distrib(avg=10, var=5)

# %%
# coal = 47 * np.random.beta(0.5,0.5,1)[0]
plot_distrib(avg=0.5, var=0.5, distrib=stats.beta.pdf, size =4)

# %%
# book = np.random.chisquare(2,1)[0]
plot_distrib(avg=2, var=1, distrib=stats.chi2.pdf,size=8)

# %%
# doll = np.random.gamma(5,1,1)[0]
plot_distrib(avg=5, var=1, distrib=stats.gamma.pdf, size=7)

# %%
# block = np.random.triangular(5,10,20,1)[0]
plot_triangular(5, 10, 20)
# Out:
# [ 0.          0.3030303   0.60606061  0.90909091  1.21212121  1.51515152
#   1.81818182  2.12121212  2.42424242  2.72727273  3.03030303  3.33333333
#   3.63636364  3.93939394  4.24242424  4.54545455  4.84848485  5.15151515
#   5.45454545  5.75757576  6.06060606  6.36363636  6.66666667  6.96969697
#   7.27272727  7.57575758  7.87878788  8.18181818  8.48484848  8.78787879
#   9.09090909  9.39393939  9.6969697  10.         10.3030303  10.60606061
#  10.90909091 11.21212121 11.51515152 11.81818182 12.12121212 12.42424242
#  12.72727273 13.03030303 13.33333333 13.63636364 13.93939394 14.24242424
#  14.54545455 14.84848485 15.15151515 15.45454545 15.75757576 16.06060606
#  16.36363636 16.66666667 16.96969697 17.27272727 17.57575758 17.87878788
#  18.18181818 18.48484848 18.78787879 19.09090909 19.39393939 19.6969697
#  20.         20.3030303  20.60606061 20.90909091 21.21212121 21.51515152
#  21.81818182 22.12121212 22.42424242 22.72727273 23.03030303 23.33333333
# ...

# %%
# gloves = 3.0 + np.random.rand(1)[0] if np.random.rand(1) < 0.3 else np.random.rand(1)[0]
# Care about the rule! It was hard to show that in an easy way on a plot.
plot_distrib(avg=0, var=1,distrib=stats.uniform.pdf, shift = 3)
