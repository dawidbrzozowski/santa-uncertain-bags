# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %%
def plot_distrib(avg, var, shift=0, size=5, distrib=stats.norm.pdf, mult=1):
    sigma = math.sqrt(var)
    x = np.linspace(avg - size*sigma, avg + size*sigma, 100)
    plt.plot(mult*x, distrib(x - shift, avg, sigma))
    plt.show()

# %%
def plot_triangular(left, mode, right): #needs to be corrected
    h = plt.hist(np.random.triangular(left, mode, right, 10000), bins=200)
    plt.show()

# %%
# horse = max(0, np.random.normal(5,2,1)[0])
plot_distrib(avg=5, var=2, distrib = stats.norm.pdf)

# %%
# ball = max(0, 1 + np.random.normal(1,0.3,1)[0])
plot_distrib(avg=1, var=0.3, shift=1)

# %%
# bike = max(0, np.random.normal(20,10,1)[0])
plot_distrib(avg=20, var=10)

# %%
# train = max(0, np.random.normal(10,5,1)[0])
plot_distrib(avg=10, var=5)

# %%
# coal = 47 * np.random.beta(0.5,0.5,1)[0]
plot_distrib(avg=0.5, var=0.5, distrib=stats.beta.pdf, size=4, mult=47)

# %%
# book = np.random.chisquare(2,1)[0]
plot_distrib(avg=2, var=1, distrib=stats.chi2.pdf,size=8)

# %%
# doll = np.random.gamma(5,1,1)[0]
plot_distrib(avg=5, var=1, distrib=stats.gamma.pdf, size=7)

# %%
# block = np.random.triangular(5,10,20,1)[0]
plot_triangular(5, 10, 20)

# %%
# gloves = 3.0 + np.random.rand(1)[0] if np.random.rand(1) < 0.3 else np.random.rand(1)[0]
# Care about the rule! It was hard to show that in an easy way on a plot.
plot_distrib(avg=0, var=1,distrib=stats.uniform.pdf, shift = 3)

# %%
def plot_distrib_2(gift):
    mu, sigma = stats.norm.fit(gift)
    plt.hist(gift, bins=25, density=True, alpha=0.7, color='g')
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = stats.norm.pdf(x, mu, sigma)
    plt.plot(x, p, color='b', linewidth=2)
    title = "Fit results: mu = %.2f, sigma = %.2f" % (mu, sigma)
    plt.title(title)
    plt.show()

# %%
size = 10000

horse = np.maximum(0, np.random.normal(5,2,size))
ball = np.maximum(0, 1 + np.random.normal(1,0.3,size))
bike = np.maximum(0, np.random.normal(20,10,size))
train = np.maximum(0, np.random.normal(10,5,size))
coal = 47 * np.random.beta(0.5,0.5,size)
book = np.random.chisquare(2,size)
doll = np.random.gamma(5,1,size)
block = np.random.triangular(5,10,20,size)
gloves = np.random.rand(size);

print(np.random.rand(size))

for i in range(len(gloves)):
    if gloves[i] < 0.3:
        gloves[i] = 3 + np.random.rand(1)[0]
    else:
        gloves[i] = np.random.rand(1)[0]
# Out:
# [0.83415788 0.56810091 0.70930225 ... 0.78087464 0.91699904 0.19888939]

# %%
# Horse
plot_distrib_2(horse)

# %%
# Ball
plot_distrib_2(ball)

# %%
# Bike
plot_distrib_2(bike)

# %%
# Train
plot_distrib_2(train)

# %%
# Coal
plot_distrib_2(coal)

# %%
# Book
plot_distrib_2(book)

# %%
# Doll
plot_distrib_2(doll)

# %%
# Block
plot_distrib_2(block)

# %%
# Gloves
plot_distrib_2(gloves)
